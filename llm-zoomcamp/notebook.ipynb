# %%
from dotenv import load_dotenv
load_dotenv()  # take environment variables from .env.

from openai import OpenAI
import os

# %%
client = OpenAI(
    api_key=os.getenv("GROQ_API_KEY"),
    base_url="https://api.groq.com/openai/v1"
)

# %%
def llm_query(prompt):
    response = client.chat.completions.create(
        model="llama-3.1-8b-instant",
        messages=[
            {
                "role": "user",
                "content": prompt
            }
        ]
    )
    return response.choices[0].message.content

# %%
question = "5+5? give me only the result, no explanation"
question1 = "give me the link of facebook"

response = llm_query(question1)

print(response)
# Out:
# I'm a large language model, I don't have the ability to provide direct links. However, I can provide you with the Facebook URL:
#
# https://www.facebook.com/
#
# You can copy and paste this into your web browser to access Facebook.
